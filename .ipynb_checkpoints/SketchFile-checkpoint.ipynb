# %% [markdown]
# # Zombie modelling

# %%
# Import dependencies

import os
import matplotlib.pyplot as plt
import numpy as np

import rasterio
from rasterio.plot import show

# %% [markdown]
# ## Format population density map
# The data is a map of the population density of Germany in 2020, at a resolution of approximately 1km^2 per pixel

# %%
# The population density map is at the following location
file = 'Data/PopDensity/Germany/2020/deu_pd_2020_1km_UNadj.tif'


with rasterio.open(file) as src:
    band = src.read(1)
    meta = src.meta
    transform = src.transform
    mask = ~src.read_masks(1)

# %%
print(f'The shape of the image is {band.shape}')
print(f'The shape of the mask is {mask.shape}')
print(f'The mask is represented in the image by pixels with a value of {meta["nodata"]}')
# Out:
# The shape of the image is (934, 1100)
# The shape of the mask is (934, 1100)
# The mask is represented in the image by pixels with a value of -99999.0

# %%
# The mask is an array where the pixels for which we have data are white (0), and black (255)
plt.imshow(mask, cmap='Greys')
plt.show()

# %%
# We can apply the mask to our data to obtain only the parts for which we have data
masked_band = np.ma.masked_array(band, mask = mask)

# %%
# Let#s visualise this data now
plt.imshow(masked_band)
plt.show()

# %%
# Zooming in on Berlin, we see
plt.imshow(masked_band[250:350,850:950])
plt.show()
